# %%
'''!pip install mlxtend
# !pip install onnxmltools
# !pip install onnxruntime '''
# Out:
# '!pip install mlxtend\n!pip install onnxmltools\n!pip install onnxruntime '

# %%
# pip install onnxconverter-common

# %%
pip install skl2onnx
# Out:
# Collecting skl2onnx
#   Obtaining dependency information for skl2onnx from https://files.pythonhosted.org/packages/26/80/836824c62ff0923b4c3b8af8332170bdc3ccb469a220535b40405a93b4fb/skl2onnx-1.16.0-py2.py3-none-any.whl.metadata
#   Using cached skl2onnx-1.16.0-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: onnx>=1.2.1 in c:\users\tariq\anaconda3\lib\site-packages (from skl2onnx) (1.16.0)
# Requirement already satisfied: scikit-learn>=0.19 in c:\users\tariq\anaconda3\lib\site-packages (from skl2onnx) (1.3.0)
# Requirement already satisfied: onnxconverter-common>=1.7.0 in c:\users\tariq\anaconda3\lib\site-packages (from skl2onnx) (1.14.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\tariq\anaconda3\lib\site-packages (from onnx>=1.2.1->skl2onnx) (1.24.3)
# Requirement already satisfied: protobuf>=3.20.2 in c:\users\tariq\anaconda3\lib\site-packages (from onnx>=1.2.1->skl2onnx) (3.20.2)
# Requirement already satisfied: packaging in c:\users\tariq\anaconda3\lib\site-packages (from onnxconverter-common>=1.7.0->skl2onnx) (23.1)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\tariq\anaconda3\lib\site-packages (from scikit-learn>=0.19->skl2onnx) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\tariq\anaconda3\lib\site-packages (from scikit-learn>=0.19->skl2onnx) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\tariq\anaconda3\lib\site-packages (from scikit-learn>=0.19->skl2onnx) (2.2.0)
# Using cached skl2onnx-1.16.0-py2.py3-none-any.whl (298 kB)
# Installing collected packages: skl2onnx
# Successfully installed skl2onnx-1.16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import torch
import pandas as pd
import sklearn
import random

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim


import matplotlib.pyplot as plt

from mlxtend.plotting import heatmap
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader

from sklearn.metrics import r2_score

import onnxruntime as rt
import onnxmltools

from skl2onnx.common.data_types import FloatTensorType

# PARAMETERS

batch_size    = 16
learning_rate = 0.005 ## 0.001
N_Epochs      = 100

epsilon = 0.0001


# Read the data

path_data = r'data.csv'

Student_Data = pd.read_csv( path_data, delimiter=";" )

headers_list = Student_Data.columns.values.tolist()


# Data Analysis

headers_list = Student_Data.columns.values.tolist()

Student_Data_np = Student_Data.to_numpy()


X = Student_Data_np[:, :-1]


y = Student_Data_np[:, 35:36]

random_seed = int( random.random() * 100 )     ## 42

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_seed)


## fix data type

X_train = X_train.astype(  np.float32  )
X_test  = X_test.astype(   np.float32  )
y_train = y_train.astype(  np.float32  )
y_test  = y_test.astype(   np.float32  )

X_train_tr = torch.from_numpy(X_train)
X_test_tr  = torch.from_numpy(X_test)
y_train_tr = torch.from_numpy(y_train)
y_test_tr  = torch.from_numpy(y_test)


x_means      = X_train_tr.mean(0, keepdim=True ) 

x_deviations = X_train_tr.std( 0, keepdim=True) + epsilon

train_ds = TensorDataset( X_train_tr, y_train_tr  )

train_dl = DataLoader( train_ds, batch_size, shuffle=True  )


## Linear Regression

class LinRegNet(nn.Module):
    ## init the class
    def __init__(self, x_means, x_deviations):
        super().__init__()
        
        self.x_means      = x_means
        self.x_deviations = x_deviations
        
        self.linear1 = nn.Linear(11, 1)
        
    ## perform inference
    def forward(self, x):
        
        x = (x - self.x_means) / self.x_deviations
        
        y_pred = self.linear1(x)
        ## return torch.round( y_pred )
        return y_pred
    
    
    


## MLP

class MLP_Net(nn.Module):
    ## init the class
    def __init__(self, x_means, x_deviations):
        super().__init__()
        
        self.x_means      = x_means
        self.x_deviations = x_deviations
        
        self.linear1 = nn.Linear(11, 8)
        self.act1    = nn.Sigmoid()
        self.linear2 = nn.Linear(8, 1)
        self.dropout = nn.Dropout(0.25)
        
    ## perform inference
    def forward(self, x):
        
        x = (x - self.x_means) / self.x_deviations
        
        x = self.linear1(x)
        x = self.act1(x)
        x = self.dropout(x)
        y_pred = self.linear2(x)
        
        ## return torch.round( y_pred )
        return y_pred
        

        

## Deep Learning with 2 hidden layers

class DL_Net(nn.Module):
    ## init the class
    def __init__(self, x_means, x_deviations):
        super().__init__()
        
        self.x_means      = x_means
        self.x_deviations = x_deviations
        
        self.linear1 = nn.Linear(36, 10)
        self.act1    = nn.ReLU()
        self.linear2 = nn.Linear(10, 6)
        self.act2    = nn.ReLU()
        self.linear3 = nn.Linear(6, 1)
        self.dropout = nn.Dropout(0.25)
        
    ## perform inference
    def forward(self, x):
        
        x = (x - self.x_means) / self.x_deviations
        
        x = self.linear1(x)
        x = self.act1(x)
        x = self.linear2(x)
        x = self.act2(x)
        ## x = self.dropout(x)
        y_pred = self.linear3(x)
        
        ## return torch.round( y_pred )
        return y_pred



## Linear plus Nonlinear
## f1 + f2

class LinearPlusNonLinear_Net(nn.Module):
    ## init the class
    def __init__(self, x_means, x_deviations):
        super().__init__()
        
        self.x_means      = x_means
        self.x_deviations = x_deviations
        
        ## F1
        self.f1_linear1 = nn.Linear(11, 1)
        
        ## F2
        self.f2_linear1 = nn.Linear(11, 14)
        self.f2_act1    = nn.Sigmoid()
        self.f2_linear2 = nn.Linear(14, 1)
        
    
    ## perform inference
    def forward(self, x):
        
        x = (x - self.x_means) / self.x_deviations
        
        ## F1
        f1 = self.f1_linear(x)
        
        ## F2
        f2 = self.f2_linear1(x)
        f2 = self.f2_act1(f2)
        f2 = self.f2_linear2(f2)
        
        y_pred = f1 + f2
        
        ## return torch.round( y_pred )
        return y_pred



def training_loop( N_Epochs, model, loss_fn, opt  ):
    
    for epoch in range(N_Epochs):
        for xb, yb in train_dl:
            
            y_pred = model(xb)
            loss   = loss_fn(y_pred, yb)
            
            opt.zero_grad()
            loss.backward()
            opt.step()
            
        if epoch % 20 == 0:
            print(epoch, "loss=", loss)


## model = LinRegNet( x_means, x_deviations  )
model = DL_Net( x_means, x_deviations  )

opt     = torch.optim.Adam(    model.parameters(), lr=learning_rate )
loss_fn = F.mse_loss

training_loop(  N_Epochs, model, loss_fn, opt  )



# Evaluate the Model

y_pred_test = model( X_test_tr )
# Out:
# 0 loss= tensor(0.0916, grad_fn=<MseLossBackward0>)
# 20 loss= tensor(0.0006, grad_fn=<MseLossBackward0>)
# 40 loss= tensor(0.0024, grad_fn=<MseLossBackward0>)
# 60 loss= tensor(0.0005, grad_fn=<MseLossBackward0>)
# 80 loss= tensor(0.0002, grad_fn=<MseLossBackward0>)

# %%
list_preds = []
list_reals = []

for i in range(len(X_test_tr)):
    print("************************************")
    print("pred, real")
    np_real =   y_test_tr[i].detach().numpy()
    np_pred = y_pred_test[i].detach().numpy()
    print(( np_pred  , np_real))
    list_preds.append(np_pred[0])
    list_reals.append(np_real[0])
# Out:
# ************************************
# pred, real
# (array([1.7297809], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-0.9075897], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([1.7480125], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-4.0211234], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([1.7707403], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([-3.1130538], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([1.7458451], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([0.30407813], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-4.03842], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([0.32294026], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([1.7294738], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([0.3136064], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([0.33479396], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-1.6972234], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([3.496558], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([-1.6888586], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([1.77688], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([-0.89605606], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([1.7726355], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([1.7802722], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([-3.1088326], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-1.6867074], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([-1.6864929], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([1.744828], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([1.7321882], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([2.0377667], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([1.7725365], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([-3.1171386], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-4.030592], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([1.8059363], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([-4.024274], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([1.762646], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([2.024629], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([0.77669215], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([-1.6843573], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([-1.7082711], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([-3.1240149], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([0.33568338], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([1.7522275], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-3.1080046], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([0.7871394], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([-3.118387], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-0.9143398], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([1.7425048], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([3.505395], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([-3.1141627], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([1.7869794], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-1.6684954], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([2.0325375], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([2.023816], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([0.8125869], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([-3.1076045], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([2.0425358], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([0.32772103], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-1.6808047], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([-4.0278053], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([1.7775519], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([0.32960525], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([0.8055353], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([0.3336393], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-3.106927], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-3.113896], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-3.1167095], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-3.1141171], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([0.8011372], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([2.02848], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([-1.6807115], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([0.32842705], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-3.1195185], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-3.1116126], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([0.3483086], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([3.5261981], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([0.32492277], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-0.92106044], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([1.7450016], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([0.3084469], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-1.6880388], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([1.7952111], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([0.3181667], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-0.90545774], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([-3.1110191], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([1.774107], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([1.7457349], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([0.33061507], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([1.7282345], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([1.7691483], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([0.32646474], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([0.32428375], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-1.685554], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([3.492603], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([1.7179005], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([2.0370915], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([1.7536132], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-3.1202118], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([1.751785], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-3.0983737], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-3.1108277], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([0.3189644], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([1.9981253], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([-3.1052916], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([0.32040688], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-3.1128693], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-3.1205173], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-4.0273337], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([3.4745636], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([2.0125892], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([-3.1152947], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-4.0132837], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([2.002597], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([3.484663], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([-4.0220156], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([2.0133202], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([-0.92530084], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([2.0336988], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([2.0303411], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([-1.7023549], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([0.7927109], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([2.027905], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([0.33336976], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([1.7503703], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-0.9110811], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([-0.9042723], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([-4.0273156], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([0.3210095], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([0.78360105], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([2.0231845], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([-4.0297427], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([1.7448752], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([1.748199], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-0.9217799], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([0.32609907], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([0.83665764], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([-0.9085494], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([-1.6819651], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([-0.97201633], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([3.5141342], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([1.7674847], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-1.6892902], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([1.7530196], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-4.0330834], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([-0.9057337], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([-0.9136169], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([2.0301492], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([-3.095784], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-3.1128814], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([0.31140414], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([0.32036862], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-0.9037167], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([1.7787795], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([2.0396352], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([2.0192947], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([-3.1046205], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([0.30899444], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([0.321673], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-0.9073924], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([3.4897263], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([0.7987927], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([-3.1088607], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([0.79585576], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([-1.6899915], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([-4.0304484], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([0.7886379], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([1.7687898], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([-3.1120193], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([1.7744491], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([0.32442096], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([3.5125062], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([2.0314143], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([1.7992351], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([0.79982114], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([-1.6751313], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([-1.6755743], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([3.52653], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([1.7316141], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-1.6714432], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([-1.6739211], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([-3.1110325], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([1.7844403], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([1.7346482], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([3.5122352], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([1.7392974], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-1.6714376], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([-3.1111891], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([1.742599], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([0.79522014], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([-0.8930224], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([2.0387135], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([0.31768486], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([1.753262], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([2.0328937], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([0.35451433], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([0.3270047], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-4.041575], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([1.7675028], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([-1.6948693], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([-3.1144152], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-3.1118052], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-3.1116886], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([0.30413237], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([1.7673535], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([0.76948977], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([0.32346764], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-3.1019468], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([1.7921474], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([2.023457], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([-4.0299644], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([-1.6771722], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([0.32540897], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([0.8044479], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([0.32320252], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-4.0251637], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([1.747412], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([0.31922594], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([1.783555], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([1.7836583], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([3.500032], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([0.33128706], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-3.1169648], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([1.7614088], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([-3.1093419], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([1.7678483], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([2.0371337], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([0.7970998], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([0.7661884], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([3.5048673], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([-0.9126502], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([-0.9145217], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([-0.92110074], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([0.78725386], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([1.7463796], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([2.0392587], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([0.80326486], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([-4.035508], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([1.7534845], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([1.7469544], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([2.0350213], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([0.31706324], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-4.032202], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([2.0388305], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([-4.033389], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([-4.026208], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([0.34168056], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([0.7692958], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([-4.0427337], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([3.4942505], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([-4.041288], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([-4.026123], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([-4.045092], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([0.803241], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([0.8029567], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([0.32099262], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-0.93820834], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([1.7773268], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([0.33656284], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([0.31351724], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-0.9116942], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([1.7902329], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([3.4847813], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([1.7444513], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-4.0069685], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([0.33350208], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([1.7537448], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([0.3230416], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([0.34581098], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([2.0188646], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([1.7477767], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([1.7854497], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([1.792723], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([3.515735], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([-3.1109064], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([0.33230475], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-4.037328], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([-3.1071532], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([0.32619342], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-4.029728], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([3.5061457], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([0.29791835], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([2.0288267], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([2.0293393], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([-4.028157], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([1.7586906], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([3.5060406], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([-3.1186295], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([0.32378986], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([0.3141977], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([3.5049317], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([0.807497], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([2.0234427], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([-3.1130767], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-4.038163], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([0.32709435], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([0.3370233], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-1.6905417], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([3.5252268], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([-3.1064334], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([1.7467849], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-1.6834574], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([3.5140262], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([1.7400179], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-3.125311], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([2.0209053], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([-3.112751], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-4.04247], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([1.7491484], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([2.0239806], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([-1.6814133], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([1.7816601], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([1.7848711], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([0.3216749], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([1.7543566], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([0.8002937], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([-3.12021], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-4.0468507], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([-3.1097665], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-1.6894852], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([3.502503], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([3.502417], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([1.7963235], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([-0.9152883], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([2.0119176], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([3.505613], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([0.32935432], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([0.33663282], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([2.0348856], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([-4.058997], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([3.4905777], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([0.3740733], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([1.7588184], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([1.78654], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([1.7482431], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([1.7895827], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([1.7957528], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([0.32835177], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([0.79168], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([-0.93015933], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([1.754147], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-3.1206534], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([2.0628598], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([1.7991757], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([1.7535253], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([0.32065424], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([1.745734], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([2.0370088], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([1.746072], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([0.32248405], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-0.9149922], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([0.8109436], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([-0.91638714], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([-3.116171], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-3.1146646], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([1.7331438], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-4.0681286], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([1.7734318], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([-3.103591], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([1.7727046], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([1.7300811], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([1.7738776], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([2.0358524], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([0.78277326], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([-4.0289903], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([-0.92703384], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([0.78583515], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([-1.6837115], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([-3.1067502], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([1.7961485], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([1.7802477], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([1.748651], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-1.6630458], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([-1.6930194], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([1.7860904], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([-3.1169748], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([2.0448508], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([3.4975674], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([-3.103018], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([2.023111], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([-4.0353475], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([-4.0389094], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([1.7876196], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([1.7964332], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([-4.030374], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([1.7916183], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([-0.9143282], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([1.7720206], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([0.34198406], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([0.7998934], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([-4.0176454], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([-4.0090756], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([1.7435155], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-4.0142474], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([1.789392], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([0.32209238], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([0.79234123], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([2.0002294], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([0.31633833], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-1.6622345], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([0.32396713], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-4.0365343], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([1.7874691], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([1.7835915], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([-1.6885505], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([0.7871611], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([3.478305], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([1.7466724], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-3.1158323], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([1.7417552], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-4.0181074], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([3.4992328], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([2.024344], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([1.742173], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([3.5199485], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([1.7834771], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([-0.9094354], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([1.7704263], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([2.0396416], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([3.5100825], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([0.80195165], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([1.7907629], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([3.511962], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# ...
# ************************************
# pred, real
# (array([-0.9116194], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([0.78576875], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([-3.1010375], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([1.7821124], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-3.1125124], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-1.686662], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([1.7602448], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-4.0147552], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([3.4655354], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([1.7916605], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([-0.90409267], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([3.4945583], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([-1.6739953], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([3.4926603], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([1.7780905], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-3.102374], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-0.91129243], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([-1.7025522], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([1.7932172], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([1.7530909], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([0.32011655], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-4.0568748], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([0.8008516], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([-4.041857], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([0.33489934], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-0.89784265], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([0.31858233], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-1.6765609], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([-0.8992826], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([0.32352737], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-1.6812111], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([0.782223], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([0.3343884], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([2.0278738], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([0.32013503], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([3.5171118], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([1.7828553], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([0.79576504], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([1.7512877], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-4.0366364], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([-3.1164215], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([1.7439492], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([0.29968956], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([0.81119907], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([-1.689585], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([1.9870503], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([3.5147066], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([0.34237322], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([3.4676588], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([-4.032065], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([-1.6782432], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([1.7427905], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-3.0829663], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([0.3241364], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-1.6814182], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([-0.8955065], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([-3.104315], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([2.0371275], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([-4.050757], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([-1.6796098], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([-3.1009626], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-0.9231262], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([-3.108263], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([1.7876801], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([0.76562893], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([1.7851498], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([-1.6859941], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([3.5123587], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([1.7764561], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-0.92161417], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([0.32679597], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-0.90621746], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([2.0291362], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([1.744659], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([3.499202], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([0.7794764], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([1.7561204], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-3.0771122], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([1.7568562], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-4.0377035], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([-3.1123369], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-1.6911802], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([1.7776101], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([3.508563], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([1.7437859], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([3.4945478], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([-1.6923672], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([1.752536], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-4.025763], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([-3.1075468], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([1.7736316], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([0.32618305], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([2.0212162], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([0.30516413], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([2.0203104], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([-1.6855404], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([2.0210907], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([0.79881966], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([-4.0308127], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([-3.12125], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-0.90907764], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([0.32910004], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-3.1216125], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-1.6805385], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([0.32963648], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([3.4937694], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([1.7464373], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([-3.1139865], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([2.0303352], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([0.80090296], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([-4.019602], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([-4.020303], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([3.5072637], dtype=float32), array([3.51], dtype=float32))
# ************************************
# pred, real
# (array([-4.0372624], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([2.047191], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([-3.1148956], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-3.1156204], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([1.7812169], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([-3.1070573], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([0.78826904], dtype=float32), array([0.79], dtype=float32))
# ************************************
# pred, real
# (array([0.33768734], dtype=float32), array([0.32], dtype=float32))
# ************************************
# pred, real
# (array([-3.1121557], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([2.030593], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([1.7881258], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([1.7775466], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([-0.90556276], dtype=float32), array([-0.92], dtype=float32))
# ************************************
# pred, real
# (array([1.7425454], dtype=float32), array([1.74], dtype=float32))
# ************************************
# pred, real
# (array([1.7874262], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([-1.6677275], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([-3.1057975], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-4.0136914], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([-1.663479], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([1.7914281], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([-3.1167583], dtype=float32), array([-3.12], dtype=float32))
# ************************************
# pred, real
# (array([-4.0299745], dtype=float32), array([-4.06], dtype=float32))
# ************************************
# pred, real
# (array([2.03263], dtype=float32), array([2.02], dtype=float32))
# ************************************
# pred, real
# (array([-1.659582], dtype=float32), array([-1.7], dtype=float32))
# ************************************
# pred, real
# (array([1.7825873], dtype=float32), array([1.79], dtype=float32))
# ************************************
# pred, real
# (array([-1.7250458], dtype=float32), array([-1.7], dtype=float32))

# %%
model.eval()

dummy_input = torch.randn(1, 36)

input_names  = ["input1"]
output_names = ["output1"]

torch.onnx.export(
        model, 
        dummy_input,
        "DLnet_StudentData.onnx",
        verbose=False,
        input_names = input_names,
        output_names = output_names
        
)

# %%
import xgboost as xgb

regressor = xgb.XGBRegressor(

        n_estimators=100,
        reg_lambda=1,
        gamma=0,
        max_depth=3
)


regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)

# %%
initial_types = [(
          'float_input',
          FloatTensorType(  [None, 36 ]  )

)]

onnx_model = onnxmltools.convert_xgboost(regressor, initial_types=initial_types)

onnxmltools.utils.save_model(onnx_model, 'Student_Dropout.onnx')

# %%
sess = rt.InferenceSession('Student_Dropout.onnx')

input_name = sess.get_inputs()[0].name

label_name = sess.get_outputs()[0].name

pred_ort = sess.run(  [label_name], {input_name: X_test.astype(np.float32)}  )

# %%
Student_Data
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                17                  5     171
# 1                  1                15                  1    9254
# 2                  1                 1                  5    9070
# 3                  1                17                  2    9773
# 4                  2                39                  1    8014
# ...              ...               ...                ...     ...
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance\t  Previous qualification  \
# 0                                1                       1
# 1                                1                       1
# 2                                1                       1
# 3                                1                       1
# 4                                0                       1
# ...                            ...                     ...
# 4419                             1                       1
# 4420                             1                       1
# 4421                             1                       1
# 4422                             1                       1
# 4423                             1                       1
#
#       Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                              122.0            1                      19
# 1                              160.0            1                       1
# 2                              122.0            1                      37
# 3                              122.0            1                      38
# 4                              100.0            1                      37
# ...                              ...          ...                     ...
# 4419                           125.0            1                       1
# 4420                           120.0          105                       1
# 4421                           154.0            1                      37
# 4422                           180.0            1                      37
# 4423                           152.0           22                      38
#
#       Father's qualification  ...  Curricular units 2nd sem (credited)  \
# 0                         12  ...                                    0
# 1                          3  ...                                    0
# 2                         37  ...                                    0
# 3                         37  ...                                    0
# 4                         38  ...                                    0
# ...                      ...  ...                                  ...
# 4419                       1  ...                                    0
# 4420                       1  ...                                    0
# 4421                      37  ...                                    0
# 4422                      37  ...                                    0
# 4423                      37  ...                                    0
#
#       Curricular units 2nd sem (enrolled)  \
# 0                                       0
# 1                                       6
# 2                                       6
# 3                                       6
# 4                                       6
# ...                                   ...
# 4419                                    6
# 4420                                    6
# 4421                                    8
# 4422                                    5
# 4423                                    6
#
#       Curricular units 2nd sem (evaluations)  \
# 0                                          0
# 1                                          6
# 2                                          0
# 3                                         10
# 4                                          6
# ...                                      ...
# 4419                                       8
# 4420                                       6
# 4421                                       9
# 4422                                       6
# 4423                                       6
#
#       Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                       0                          0.000000
# 1                                       6                         13.666667
# 2                                       0                          0.000000
# 3                                       5                         12.400000
# 4                                       6                         13.000000
# ...                                   ...                               ...
# 4419                                    5                         12.666667
# 4420                                    2                         11.000000
# 4421                                    1                         13.500000
# 4422                                    5                         12.000000
# 4423                                    6                         13.000000
#
#       Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                                  0               10.8
# 1                                                  0               13.9
# 2                                                  0               10.8
# 3                                                  0                9.4
# 4                                                  0               13.9
# ...                                              ...                ...
# 4419                                               0               15.5
# 4420                                               0               11.1
# 4421                                               0               13.9
# 4422                                               0                9.4
# 4423                                               0               12.7
#
#       Inflation rate   GDP    Target
# 0                1.4  1.74   Dropout
# 1               -0.3  0.79  Graduate
# 2                1.4  1.74   Dropout
# 3               -0.8 -3.12  Graduate
# 4               -0.3  0.79  Graduate
# ...              ...   ...       ...
# 4419             2.8 -4.06  Graduate
# 4420             0.6  2.02   Dropout
# 4421            -0.3  0.79   Dropout
# 4422            -0.8 -3.12  Graduate
# 4423             3.7 -1.70  Graduate
#
# [4424 rows x 37 columns]

# %%
headers_list = Student_Data.columns.values.tolist()

headers_list
# Out:
# ['Marital status',
#  'Application mode',
#  'Application order',
#  'Course',
#  'Daytime/evening attendance\t',
#  'Previous qualification',
#  'Previous qualification (grade)',
#  'Nacionality',
#  "Mother's qualification",
#  "Father's qualification",
#  "Mother's occupation",
#  "Father's occupation",
#  'Admission grade',
#  'Displaced',
#  'Educational special needs',
#  'Debtor',
#  'Tuition fees up to date',
#  'Gender',
#  'Scholarship holder',
#  'Age at enrollment',
#  'International',
#  'Curricular units 1st sem (credited)',
#  'Curricular units 1st sem (enrolled)',
#  'Curricular units 1st sem (evaluations)',
#  'Curricular units 1st sem (approved)',
#  'Curricular units 1st sem (grade)',
#  'Curricular units 1st sem (without evaluations)',
#  'Curricular units 2nd sem (credited)',
#  'Curricular units 2nd sem (enrolled)',
#  'Curricular units 2nd sem (evaluations)',
#  'Curricular units 2nd sem (approved)',
#  'Curricular units 2nd sem (grade)',
#  'Curricular units 2nd sem (without evaluations)',
#  'Unemployment rate',
#  'Inflation rate',
#  'GDP',
#  'Target']

# %%
# Out:
# array([[1, 17, 5, ..., 1.4, 1.74, 'Dropout'],
#        [1, 15, 1, ..., -0.3, 0.79, 'Graduate'],
#        [1, 1, 5, ..., 1.4, 1.74, 'Dropout'],
#        ...,
#        [1, 1, 1, ..., -0.3, 0.79, 'Dropout'],
#        [1, 1, 1, ..., -0.8, -3.12, 'Graduate'],
#        [1, 10, 1, ..., 3.7, -1.7, 'Graduate']], dtype=object)

# %%
# Out:
# (4424, 37)

# %%
# Out:
# array([[1.74],
#        [0.79],
#        [1.74],
#        ...,
#        [0.79],
#        [-3.12],
#        [-1.7]], dtype=object)

# %%
# Out:
# (4424, 36)
# (4424, 1)

# %%
# Out:
# (3539, 36)
# (885, 36)
# (3539, 1)
# (885, 1)

# %%
# Out:
# dtype('O')

# %%
# Out:
# tensor([[ 1.1763e+00,  1.8610e+01,  1.7327e+00,  8.8605e+03,  8.9206e-01,
#           4.6369e+00,  1.3260e+02,  1.8519e+00,  1.9566e+01,  2.2390e+01,
#           1.0880e+01,  1.0954e+01,  1.2697e+02,  5.4987e-01,  1.2715e-02,
#           1.1077e-01,  8.8471e-01,  3.5010e-01,  2.5600e-01,  2.3234e+01,
#           2.2888e-02,  6.9087e-01,  6.2484e+00,  8.2766e+00,  4.6847e+00,
#           1.0629e+01,  1.2998e-01,  5.3009e-01,  6.2122e+00,  8.0206e+00,
#           4.4295e+00,  1.0246e+01,  1.5202e-01,  1.1594e+01,  1.2267e+00,
#          -1.4524e-03]])

# %%
# Out:
# tensor([[5.9828e-01, 1.7437e+01, 1.3150e+00, 2.0605e+03, 3.1045e-01, 1.0298e+01,
#          1.3296e+01, 6.9632e+00, 1.5593e+01, 1.5318e+01, 2.5961e+01, 2.4980e+01,
#          1.4618e+01, 4.9768e-01, 1.1216e-01, 3.1399e-01, 3.1951e-01, 4.7717e-01,
#          4.3659e-01, 7.6358e+00, 1.4967e-01, 2.2957e+00, 2.4406e+00, 4.1473e+00,
#          3.0555e+00, 4.8412e+00, 6.5603e-01, 1.8761e+00, 2.1719e+00, 3.9507e+00,
#          2.9896e+00, 5.2112e+00, 7.5873e-01, 2.6612e+00, 1.3874e+00, 2.2627e+00]])

# %%
# Out:
# 0 loss= tensor(0.0704, grad_fn=<MseLossBackward0>)
# 20 loss= tensor(0.0026, grad_fn=<MseLossBackward0>)
# 40 loss= tensor(0.0015, grad_fn=<MseLossBackward0>)
# 60 loss= tensor(0.0018, grad_fn=<MseLossBackward0>)
# 80 loss= tensor(0.0060, grad_fn=<MseLossBackward0>)
